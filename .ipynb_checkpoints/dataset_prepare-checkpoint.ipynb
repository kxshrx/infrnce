# %%
print("1. dataset preparation")
# Out:
# 1. dataset preparation

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('synthetic_logs.csv')
df.head()
# Out:
#        timestamp           source  \
# 0   6/27/25 7:20        ModernCRM
# 1  1/14/25 23:07        ModernCRM
# 2   1/17/25 1:29  AnalyticsEngine
# 3   7/12/25 0:24         ModernHR
# 4   6/2/25 18:25    BillingSystem
#
#                                          log_message    target_label
# 0  nova.osapi_compute.wsgi.server [req-b9718cd8-f...     HTTP Status
# 1     Email service experiencing issues with sending  Critical Error
# 2          Unauthorized access to data was attempted  Security Alert
# 3  nova.osapi_compute.wsgi.server [req-4895c258-b...     HTTP Status
# 4  nova.osapi_compute.wsgi.server [req-ee8bc8ba-9...     HTTP Status

# %%
df.shape
# Out:
# (2410, 4)

# %%
print("\nColumn names:", df.columns.tolist())
# Out:
# Column names: ['timestamp', 'source', 'log_message', 'target_label']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2410 entries, 0 to 2409
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   timestamp     2410 non-null   object
#  1   source        2410 non-null   object
#  2   log_message   2410 non-null   object
#  3   target_label  2410 non-null   object
# dtypes: object(4)
# memory usage: 75.4+ KB

# %%
df.isnull().sum()
# Out:
# timestamp       0
# source          0
# log_message     0
# target_label    0
# dtype: int64

# %%
df.head(20)
# Out:
#          timestamp           source  \
# 0     6/27/25 7:20        ModernCRM
# 1    1/14/25 23:07        ModernCRM
# 2     1/17/25 1:29  AnalyticsEngine
# 3     7/12/25 0:24         ModernHR
# 4     6/2/25 18:25    BillingSystem
# 5    10/9/25 10:30         ModernHR
# 6     3/1/25 19:14         ModernHR
# 7    10/11/25 8:44         ModernHR
# 8    2/12/25 10:42    ThirdPartyAPI
# 9     3/30/25 4:01         ModernHR
# 10    8/9/25 18:58        ModernCRM
# 11   6/15/25 11:44         ModernHR
# 12    7/12/25 3:03         ModernHR
# 13    8/4/25 19:57    ThirdPartyAPI
# 14     1/4/25 1:43    ThirdPartyAPI
# 15     5/1/25 9:41        ModernCRM
# 16  11/15/25 14:48    BillingSystem
# 17   1/27/25 12:39        ModernCRM
# 18   2/22/25 17:49        ModernCRM
# 19    7/10/25 1:17    BillingSystem
#
#                                           log_message         target_label
# 0   nova.osapi_compute.wsgi.server [req-b9718cd8-f...          HTTP Status
# ...

# %%
df['log_message'] = df['log_message'].astype(str).str.strip()

# %%
df.head(20)
# Out:
#          timestamp           source  \
# 0     6/27/25 7:20        ModernCRM
# 1    1/14/25 23:07        ModernCRM
# 2     1/17/25 1:29  AnalyticsEngine
# 3     7/12/25 0:24         ModernHR
# 4     6/2/25 18:25    BillingSystem
# 5    10/9/25 10:30         ModernHR
# 6     3/1/25 19:14         ModernHR
# 7    10/11/25 8:44         ModernHR
# 8    2/12/25 10:42    ThirdPartyAPI
# 9     3/30/25 4:01         ModernHR
# 10    8/9/25 18:58        ModernCRM
# 11   6/15/25 11:44         ModernHR
# 12    7/12/25 3:03         ModernHR
# 13    8/4/25 19:57    ThirdPartyAPI
# 14     1/4/25 1:43    ThirdPartyAPI
# 15     5/1/25 9:41        ModernCRM
# 16  11/15/25 14:48    BillingSystem
# 17   1/27/25 12:39        ModernCRM
# 18   2/22/25 17:49        ModernCRM
# 19    7/10/25 1:17    BillingSystem
#
#                                           log_message         target_label
# 0   nova.osapi_compute.wsgi.server [req-b9718cd8-f...          HTTP Status
# ...

# %%
before = len(df)
print(f"original length{before}")
df = df.drop_duplicates(subset=['log_message'])
after = len(df)
print(f"original length{after}")
# Out:
# original length2410
# original length2265

# %%
df.to_csv('cleaned_logs.csv', index=False)

# %%
new_df = pd.read_csv('cleaned_logs.csv')
new_df.head()
# Out:
#        timestamp           source  \
# 0   6/27/25 7:20        ModernCRM
# 1  1/14/25 23:07        ModernCRM
# 2   1/17/25 1:29  AnalyticsEngine
# 3   7/12/25 0:24         ModernHR
# 4   6/2/25 18:25    BillingSystem
#
#                                          log_message    target_label
# 0  nova.osapi_compute.wsgi.server [req-b9718cd8-f...     HTTP Status
# 1     Email service experiencing issues with sending  Critical Error
# 2          Unauthorized access to data was attempted  Security Alert
# 3  nova.osapi_compute.wsgi.server [req-4895c258-b...     HTTP Status
# 4  nova.osapi_compute.wsgi.server [req-ee8bc8ba-9...     HTTP Status

# %%
new_df.shape
# Out:
# (2265, 4)
